# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#    gender  study_hours  attendance  math_score  science_score  english_score
# 0    Male            2          75          55             60             58
# 1  Female            4          85          78             82             80
# 2    Male            1          65          45             50             48
# 3  Female            5          90          88             92             90
# 4    Male            3          80          65             70             68
# 5  Female            2          70          60             62             64
# 6    Male            4          88          75             78             76
# 7  Female            3          82          70             72             74
# 8    Male            5          92          85             88             86
# 9  Female            1          60          50             52             54

# %%
df.head()
# Out:
#    gender  study_hours  attendance  math_score  science_score  english_score
# 0    Male            2          75          55             60             58
# 1  Female            4          85          78             82             80
# 2    Male            1          65          45             50             48
# 3  Female            5          90          88             92             90
# 4    Male            3          80          65             70             68

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         10 non-null     object
#  1   study_hours    10 non-null     int64
#  2   attendance     10 non-null     int64
#  3   math_score     10 non-null     int64
#  4   science_score  10 non-null     int64
#  5   english_score  10 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 612.0+ bytes

# %%
df.describe()
# Out:
#        study_hours  attendance  math_score  science_score  english_score
# count    10.000000   10.000000   10.000000      10.000000      10.000000
# mean      3.000000   78.700000   67.100000      70.600000      69.800000
# std       1.490712   10.904128   14.639748      14.546477      13.870833
# min       1.000000   60.000000   45.000000      50.000000      48.000000
# 25%       2.000000   71.250000   56.250000      60.500000      59.500000
# 50%       3.000000   81.000000   67.500000      71.000000      71.000000
# 75%       4.000000   87.250000   77.250000      81.000000      79.000000
# max       5.000000   92.000000   88.000000      92.000000      90.000000

# %%
df["total_score"] = df["math_score"] + df["science_score"] + df["english_score"]
df["average_score"] = df["total_score"] / 3
df
# Out:
#    gender  study_hours  attendance  math_score  science_score  english_score  \
# 0    Male            2          75          55             60             58
# 1  Female            4          85          78             82             80
# 2    Male            1          65          45             50             48
# 3  Female            5          90          88             92             90
# 4    Male            3          80          65             70             68
# 5  Female            2          70          60             62             64
# 6    Male            4          88          75             78             76
# 7  Female            3          82          70             72             74
# 8    Male            5          92          85             88             86
# 9  Female            1          60          50             52             54
#
#    total_score  average_score
# 0          173      57.666667
# 1          240      80.000000
# ...

# %%
plt.scatter(df["study_hours"], df["average_score"])
plt.xlabel("Study Hours")
plt.ylabel("Average Score")
plt.title("Study Hours vs Average Score")
plt.show()

# %%
plt.scatter(df["attendance"], df["average_score"])
plt.xlabel("Attendance (%)")
plt.ylabel("Average Score")
plt.title("Attendance vs Average Score")
plt.show()

# %%
plt.scatter(df["attendance"], df["average_score"])
plt.xlabel("Attendance (%)")
plt.ylabel("Average Score")
plt.title("Attendance vs Average Score")
plt.show()

# %%
plt.hist(df["study_hours"], bins=5, color="skyblue", edgecolor="black")
plt.xlabel("Study Hours")
plt.ylabel("Number of Students")
plt.title("Distribution of Study Hours")
plt.show()

# %% [markdown]
# # Insights from Student Performance Analysis
#
# 1. Students who study more than 3 hours per day generally have higher average scores.
# 2. Attendance above 80% strongly correlates with better performance.
# 3. Gender alone does not significantly affect performance.
# 4. Students with both low study hours and low attendance perform the worst.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation between numeric features")
plt.show()

# %%
sns.pairplot(df, hue="gender")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="study_hours", y="average_score", data=df)
plt.title("Study Hours vs Average Score Distribution")
plt.show()

# %%
feature = "study_hours" 

plt.scatter(df[feature], df["average_score"])
plt.xlabel(feature)
plt.ylabel("Average Score")
plt.title(f"{feature} vs Average Score")
plt.show()

# %%
feature = "study_hours"  # or "attendance"

plt.scatter(df[feature], df["average_score"])
plt.xlabel(feature)
plt.ylabel("Average Score")
plt.title(f"{feature} vs Average Score")
plt.show()
